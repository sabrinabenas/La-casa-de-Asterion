# %%
import pandas as pd
import gc
import polars as pl
from tqdm.auto import tqdm
from scipy.optimize import curve_fit
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn import set_config
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from utils import *

set_config(transform_output="pandas")
pl.enable_string_cache()

## cargamos los datos
lazy_wide_df = pl.scan_parquet("../data/wide.parquet")
#print(lazy_wide_df.collect_schema())

lazy_test_df = pl.scan_parquet("../data/ids_test_expanded.parquet")

# %%
# ==========================================
# CONFIGURACIÓN DE MODELOS Y PREPROCESSORS
# ==========================================

# Configuración del preprocessor
preprocessor_region = ColumnTransformer(
    transformers=[
        (
            "onehot",
            OneHotEncoder(sparse_output=False, handle_unknown="ignore"),
            ["store_type", "brand_house", "cluster"],
        ),
        (
            "ordinal",
            OrdinalEncoder(categories=[["Primavera", "Verano", "Otoño", "Invierno"]]),
            ["estacion"],
        ),
        (
            "scaler",
            StandardScaler(),
            [   # "price",
                "residuos_precio",
                "loyalty_count", 
                "non_loyalty_count",
                "year",
                "quantity",
                "days_since_start",
                "avg_price_ratio",
                "avg_profit_ratio",
            ],
        ),
    ],
    remainder="passthrough",
)

# Pipeline optimizado
pipeline_region = make_pipeline(
    preprocessor_region,
    HistGradientBoostingRegressor(
        max_iter=200,
        max_depth=6,
        learning_rate=0.05,
        min_samples_leaf=15,
        validation_fraction=0.2,
        early_stopping=True,
        random_state=42,
    ),
)

# ==========================================
# PREPARACIÓN DE DATOS AGRUPADOS
# ==========================================

# Lazy grouped corregido para región
lazy_grouped_region = (lazy_wide_df
    # lazy_wide_df.with_columns(
    #     # (
    #     #     (pl.col("date") - pl.col("date").min()).cast(pl.Int64) / 1000 / 60 / 60 / 24
    #     # ).alias("days_since_start")
    # )
    .group_by(
        [
            "subgroup", "region", "store_id", "cluster", "store_type",
            "estacion", "day", "days_since_start", "weekday", "month", 
            "year", "brand_house", "quantity",
        ] #CHECK QUANTITY --> NO SE SI TIENE QUE ESTAR ACA O NO
    )
    .agg(
        [
            pl.col("price").mean().alias("price"),
            pl.col("total_sales").sum().alias("total_sales"),
            pl.col("day_sin").mean().alias("day_sin"),
            pl.col("day_cos").mean().alias("day_cos"),
            pl.col("weekday_sin").mean().alias("weekday_sin"),
            pl.col("weekday_cos").mean().alias("weekday_cos"),
            pl.col("month_sin").mean().alias("month_sin"),
            pl.col("month_cos").mean().alias("month_cos"),
            pl.col("loyalty_count").mean().alias("loyalty_count"),
            pl.col("non_loyalty_count").mean().alias("non_loyalty_count"),
            pl.col("base_price").mean().alias("base_price"),
            pl.col("costos").mean().alias("costos"),
            # pl.col("quantity").mean().alias("quantity"),
        ]
    )
    .with_columns(
        (pl.col("price") / pl.col("base_price")).alias("avg_price_ratio"),
        (pl.col("price") / pl.col("costos")).alias("avg_profit_ratio"),
    )
)

# %%
# ==========================================
# LOOP PRINCIPAL CON POLARS - OPTIMIZADO
# ==========================================

# Configuración
LIMIT_PRODUCTS = None
LIMIT_REGIONS = None
USE_REGIONS = False

# Variables para resultados
dict_results = {}

# Obtener listas de productos y regiones
productos = lazy_test_df.select("subgroup").unique().collect().to_pandas()["subgroup"].values
regiones = lazy_test_df.select("region").unique().collect().to_pandas()["region"].values

# Aplicar límites si están configurados
if LIMIT_PRODUCTS:
    productos = productos[:LIMIT_PRODUCTS]
if LIMIT_REGIONS:
    regiones = regiones[:LIMIT_REGIONS]

# Configurar procesamiento según USE_REGIONS
if USE_REGIONS:
    print("📊 PROCESANDO CON REGIONES SEPARADAS")
    total_combinations = len(productos) * len(regiones)
    combinations = [(prod, region) for prod in productos for region in regiones]
else:
    print("📊 PROCESANDO SIN FILTRAR POR REGIÓN")
    total_combinations = len(productos)
    combinations = [(prod, None) for prod in productos]

print("📊 CONFIGURACIÓN DE PROCESAMIENTO:")
print(f"   - Productos: {len(productos)}")
print(f"   - Regiones: {len(regiones) if USE_REGIONS else 'Todas juntas'}")
print(f"   - Total combinaciones: {total_combinations}")
print(f"   - Memoria inicial: {check_memory():.1f} MB")
print("=" * 50)

# Procesamiento optimizado
count = 0

for prod, region in tqdm(combinations, desc="Procesando combinaciones"):
    count += 1
    progress = (count / total_combinations) * 100
    
    print(f"\n🎯 PRODUCTO: {prod}")
    
    if USE_REGIONS and region:
        print(f"   🌍 Región: {region} ({count}/{total_combinations} - {progress:.1f}%)")
    else:
        print(f"   🌐 Procesando todas las regiones juntas ({count}/{total_combinations} - {progress:.1f}%)")
    
    # Caso especial: Basketball
    if prod == "Basketball":
        print("   📝 Caso especial: asignando ventas = 0")
        basketball_results = process_basketball_special_case(lazy_test_df, prod)
        dict_results.update(basketball_results)
        continue
    
    try:
        # Procesar combinación producto-región
        region_results = process_product_region_combination_polars(
            prod, region, lazy_grouped_region, lazy_wide_df, lazy_test_df, pipeline_region
        )
        
        # Agregar resultados
        dict_results.update(region_results)
        
    except Exception as e:
        print(f"   ❌ Error en {prod}-{region}: {e}")
        continue
    
    # Limpieza de memoria
    if count % 5 == 0:
        current_memory = check_memory()
        gc.collect()
        new_memory = check_memory()
        print(f"   🧹 Memoria: {current_memory:.1f} → {new_memory:.1f} MB (liberados: {current_memory-new_memory:.1f} MB)")

print("\n" + "=" * 50)
print(f"✅ PROCESAMIENTO COMPLETADO")
print(f"   - Total predicciones generadas: {len(dict_results):,}")
print(f"   - Combinaciones procesadas: {count}/{total_combinations}")
print("=" * 50)
# Out:
# 📊 PROCESANDO SIN FILTRAR POR REGIÓN
# 📊 CONFIGURACIÓN DE PROCESAMIENTO:
#    - Productos: 74
#    - Regiones: Todas juntas
#    - Total combinaciones: 74
#    - Memoria inicial: 463.6 MB
# ==================================================
# Procesando combinaciones:   0%|          | 0/74 [00:00<?, ?it/s]
# 🎯 PRODUCTO: Pants
#    🌐 Procesando todas las regiones juntas (1/74 - 1.4%)
#    Procesando: Pants - None
#    📊 Filas antes filtrado: 115,105
#    🗑️ Outliers removidos: 302 (0.3%)
#    R² ajuste sinusoidal: 0.687
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Puzzles
#    🌐 Procesando todas las regiones juntas (2/74 - 2.7%)
#    Procesando: Puzzles - None
#    📊 Filas antes filtrado: 70,102
#    🗑️ Outliers removidos: 124 (0.2%)
#    R² ajuste sinusoidal: 0.432
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Face
#    🌐 Procesando todas las regiones juntas (3/74 - 4.1%)
#    Procesando: Face - None
#    📊 Filas antes filtrado: 128,712
#    🗑️ Outliers removidos: 913 (0.7%)
#    R² ajuste sinusoidal: 0.671
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Dining
#    🌐 Procesando todas las regiones juntas (4/74 - 5.4%)
#    Procesando: Dining - None
#    📊 Filas antes filtrado: 104,308
#    🗑️ Outliers removidos: 806 (0.8%)
#    R² ajuste sinusoidal: 0.412
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Mystery
#    🌐 Procesando todas las regiones juntas (5/74 - 6.8%)
#    Procesando: Mystery - None
#    📊 Filas antes filtrado: 109,525
#    🗑️ Outliers removidos: 276 (0.3%)
#    R² ajuste sinusoidal: 0.584
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 661.1 → 741.4 MB (liberados: -80.3 MB)
#
# 🎯 PRODUCTO: Treatments
#    🌐 Procesando todas las regiones juntas (6/74 - 8.1%)
#    Procesando: Treatments - None
#    📊 Filas antes filtrado: 116,529
#    🗑️ Outliers removidos: 494 (0.4%)
#    R² ajuste sinusoidal: 0.571
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Science Fiction
#    🌐 Procesando todas las regiones juntas (7/74 - 9.5%)
#    Procesando: Science Fiction - None
#    📊 Filas antes filtrado: 119,491
#    🗑️ Outliers removidos: 234 (0.2%)
#    R² ajuste sinusoidal: 0.598
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Baking
#    🌐 Procesando todas las regiones juntas (8/74 - 10.8%)
#    Procesando: Baking - None
#    📊 Filas antes filtrado: 192,293
#    🗑️ Outliers removidos: 573 (0.3%)
#    R² ajuste sinusoidal: 0.799
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Figures
#    🌐 Procesando todas las regiones juntas (9/74 - 12.2%)
#    Procesando: Figures - None
#    📊 Filas antes filtrado: 99,639
#    🗑️ Outliers removidos: 262 (0.3%)
#    R² ajuste sinusoidal: 0.523
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Lips
#    🌐 Procesando todas las regiones juntas (10/74 - 13.5%)
#    Procesando: Lips - None
#    📊 Filas antes filtrado: 130,624
#    🗑️ Outliers removidos: 806 (0.6%)
#    R² ajuste sinusoidal: 0.635
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 686.5 → 686.5 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Utensils
#    🌐 Procesando todas las regiones juntas (11/74 - 14.9%)
#    Procesando: Utensils - None
#    📊 Filas antes filtrado: 129,498
#    🗑️ Outliers removidos: 371 (0.3%)
#    R² ajuste sinusoidal: 0.581
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Smartphones
#    🌐 Procesando todas las regiones juntas (12/74 - 16.2%)
#    Procesando: Smartphones - None
#    📊 Filas antes filtrado: 121,500
#    🗑️ Outliers removidos: 390 (0.3%)
#    R² ajuste sinusoidal: 0.603
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Reference
#    🌐 Procesando todas las regiones juntas (13/74 - 17.6%)
#    Procesando: Reference - None
#    📊 Filas antes filtrado: 126,389
#    🗑️ Outliers removidos: 237 (0.2%)
#    R² ajuste sinusoidal: 0.598
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Moisturizers
#    🌐 Procesando todas las regiones juntas (14/74 - 18.9%)
#    Procesando: Moisturizers - None
#    📊 Filas antes filtrado: 89,607
#    🗑️ Outliers removidos: 353 (0.4%)
#    R² ajuste sinusoidal: 0.513
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Baseball
#    🌐 Procesando todas las regiones juntas (15/74 - 20.3%)
#    Procesando: Baseball - None
#    📊 Filas antes filtrado: 89,065
#    🗑️ Outliers removidos: 250 (0.3%)
#    R² ajuste sinusoidal: 0.380
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 703.3 → 703.3 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Supplements
#    🌐 Procesando todas las regiones juntas (16/74 - 21.6%)
#    Procesando: Supplements - None
#    📊 Filas antes filtrado: 89,018
#    🗑️ Outliers removidos: 560 (0.6%)
#    R² ajuste sinusoidal: 0.408
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Boys
#    🌐 Procesando todas las regiones juntas (17/74 - 23.0%)
#    Procesando: Boys - None
#    📊 Filas antes filtrado: 152,864
#    🗑️ Outliers removidos: 422 (0.3%)
#    R² ajuste sinusoidal: 0.733
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Tops
#    🌐 Procesando todas las regiones juntas (18/74 - 24.3%)
#    Procesando: Tops - None
#    📊 Filas antes filtrado: 167,176
#    🗑️ Outliers removidos: 461 (0.3%)
#    R² ajuste sinusoidal: 0.724
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Bedroom
#    🌐 Procesando todas las regiones juntas (19/74 - 25.7%)
#    Procesando: Bedroom - None
#    📊 Filas antes filtrado: 123,516
#    🗑️ Outliers removidos: 919 (0.7%)
#    R² ajuste sinusoidal: 0.595
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Pasta
#    🌐 Procesando todas las regiones juntas (20/74 - 27.0%)
#    Procesando: Pasta - None
#    📊 Filas antes filtrado: 146,546
#    🗑️ Outliers removidos: 403 (0.3%)
#    R² ajuste sinusoidal: 0.712
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 772.0 → 772.0 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Pots & Pans
#    🌐 Procesando todas las regiones juntas (21/74 - 28.4%)
#    Procesando: Pots & Pans - None
#    📊 Filas antes filtrado: 112,100
#    🗑️ Outliers removidos: 385 (0.3%)
#    R² ajuste sinusoidal: 0.486
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Cookies
#    🌐 Procesando todas las regiones juntas (22/74 - 29.7%)
#    Procesando: Cookies - None
#    📊 Filas antes filtrado: 206,176
#    🗑️ Outliers removidos: 555 (0.3%)
#    R² ajuste sinusoidal: 0.829
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Living Room
#    🌐 Procesando todas las regiones juntas (23/74 - 31.1%)
#    Procesando: Living Room - None
#    📊 Filas antes filtrado: 94,143
#    🗑️ Outliers removidos: 807 (0.9%)
#    R² ajuste sinusoidal: 0.500
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Styling
#    🌐 Procesando todas las regiones juntas (24/74 - 32.4%)
#    Procesando: Styling - None
#    📊 Filas antes filtrado: 124,918
#    🗑️ Outliers removidos: 354 (0.3%)
#    R² ajuste sinusoidal: 0.585
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Bakeware
#    🌐 Procesando todas las regiones juntas (25/74 - 33.8%)
#    Procesando: Bakeware - None
#    📊 Filas antes filtrado: 111,291
#    🗑️ Outliers removidos: 329 (0.3%)
#    R² ajuste sinusoidal: 0.669
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 763.2 → 763.2 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Equipment
#    🌐 Procesando todas las regiones juntas (26/74 - 35.1%)
#    Procesando: Equipment - None
#    📊 Filas antes filtrado: 106,491
#    🗑️ Outliers removidos: 625 (0.6%)
#    R² ajuste sinusoidal: 0.545
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Board Games
#    🌐 Procesando todas las regiones juntas (27/74 - 36.5%)
#    Procesando: Board Games - None
#    📊 Filas antes filtrado: 127,118
#    🗑️ Outliers removidos: 364 (0.3%)
#    R² ajuste sinusoidal: 0.549
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Juice
#    🌐 Procesando todas las regiones juntas (28/74 - 37.8%)
#    Procesando: Juice - None
#    📊 Filas antes filtrado: 146,569
#    🗑️ Outliers removidos: 579 (0.4%)
#    R² ajuste sinusoidal: 0.679
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Self-Help
#    🌐 Procesando todas las regiones juntas (29/74 - 39.2%)
#    Procesando: Self-Help - None
#    📊 Filas antes filtrado: 101,910
#    🗑️ Outliers removidos: 261 (0.3%)
#    R² ajuste sinusoidal: 0.601
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Playsets
#    🌐 Procesando todas las regiones juntas (30/74 - 40.5%)
#    Procesando: Playsets - None
#    📊 Filas antes filtrado: 70,392
#    🗑️ Outliers removidos: 174 (0.2%)
#    R² ajuste sinusoidal: 0.435
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 885.2 → 885.2 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Home Audio
#    🌐 Procesando todas las regiones juntas (31/74 - 41.9%)
#    Procesando: Home Audio - None
#    📊 Filas antes filtrado: 98,751
#    🗑️ Outliers removidos: 415 (0.4%)
#    R² ajuste sinusoidal: 0.553
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Cleansers
#    🌐 Procesando todas las regiones juntas (32/74 - 43.2%)
#    Procesando: Cleansers - None
#    📊 Filas antes filtrado: 107,941
#    🗑️ Outliers removidos: 456 (0.4%)
#    R² ajuste sinusoidal: 0.660
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Wearables
#    🌐 Procesando todas las regiones juntas (33/74 - 44.6%)
#    Procesando: Wearables - None
#    📊 Filas antes filtrado: 121,535
#    🗑️ Outliers removidos: 334 (0.3%)
#    R² ajuste sinusoidal: 0.669
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Textbooks
#    🌐 Procesando todas las regiones juntas (34/74 - 45.9%)
#    Procesando: Textbooks - None
#    📊 Filas antes filtrado: 119,105
#    🗑️ Outliers removidos: 277 (0.2%)
#    R² ajuste sinusoidal: 0.688
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Card Games
#    🌐 Procesando todas las regiones juntas (35/74 - 47.3%)
#    Procesando: Card Games - None
#    📊 Filas antes filtrado: 108,277
#    🗑️ Outliers removidos: 270 (0.2%)
#    R² ajuste sinusoidal: 0.536
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 808.6 → 808.6 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Vehicles
#    🌐 Procesando todas las regiones juntas (36/74 - 48.6%)
#    Procesando: Vehicles - None
#    📊 Filas antes filtrado: 99,327
#    🗑️ Outliers removidos: 250 (0.3%)
#    R² ajuste sinusoidal: 0.503
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Dresses
#    🌐 Procesando todas las regiones juntas (37/74 - 50.0%)
#    Procesando: Dresses - None
#    📊 Filas antes filtrado: 113,237
#    🗑️ Outliers removidos: 300 (0.3%)
#    R² ajuste sinusoidal: 0.698
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Arts & Crafts
#    🌐 Procesando todas las regiones juntas (38/74 - 51.4%)
#    Procesando: Arts & Crafts - None
#    📊 Filas antes filtrado: 109,124
#    🗑️ Outliers removidos: 274 (0.3%)
#    R² ajuste sinusoidal: 0.649
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Jackets
#    🌐 Procesando todas las regiones juntas (39/74 - 52.7%)
#    Procesando: Jackets - None
#    📊 Filas antes filtrado: 106,480
#    🗑️ Outliers removidos: 321 (0.3%)
#    R² ajuste sinusoidal: 0.673
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: STEM
#    🌐 Procesando todas las regiones juntas (40/74 - 54.1%)
#    Procesando: STEM - None
#    📊 Filas antes filtrado: 90,220
#    🗑️ Outliers removidos: 195 (0.2%)
#    R² ajuste sinusoidal: 0.495
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 654.2 → 654.2 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Hiking
#    🌐 Procesando todas las regiones juntas (41/74 - 55.4%)
#    Procesando: Hiking - None
#    📊 Filas antes filtrado: 89,344
#    🗑️ Outliers removidos: 318 (0.4%)
#    R² ajuste sinusoidal: 0.446
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Chips
#    🌐 Procesando todas las regiones juntas (42/74 - 56.8%)
#    Procesando: Chips - None
#    📊 Filas antes filtrado: 220,801
#    🗑️ Outliers removidos: 585 (0.3%)
#    R² ajuste sinusoidal: 0.861
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Treatment
#    🌐 Procesando todas las regiones juntas (43/74 - 58.1%)
#    Procesando: Treatment - None
#    📊 Filas antes filtrado: 89,065
#    🗑️ Outliers removidos: 218 (0.2%)
#    R² ajuste sinusoidal: 0.581
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Bottoms
#    🌐 Procesando todas las regiones juntas (44/74 - 59.5%)
#    Procesando: Bottoms - None
#    📊 Filas antes filtrado: 145,495
#    🗑️ Outliers removidos: 390 (0.3%)
#    R² ajuste sinusoidal: 0.790
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Outerwear
#    🌐 Procesando todas las regiones juntas (45/74 - 60.8%)
#    Procesando: Outerwear - None
#    📊 Filas antes filtrado: 179,125
#    🗑️ Outliers removidos: 516 (0.3%)
#    R² ajuste sinusoidal: 0.766
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 779.1 → 779.1 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Girls
#    🌐 Procesando todas las regiones juntas (46/74 - 62.2%)
#    Procesando: Girls - None
#    📊 Filas antes filtrado: 113,644
#    🗑️ Outliers removidos: 323 (0.3%)
#    R² ajuste sinusoidal: 0.691
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Coffee
#    🌐 Procesando todas las regiones juntas (47/74 - 63.5%)
#    Procesando: Coffee - None
#    📊 Filas antes filtrado: 211,825
#    🗑️ Outliers removidos: 875 (0.4%)
#    R² ajuste sinusoidal: 0.821
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Tablets
#    🌐 Procesando todas las regiones juntas (48/74 - 64.9%)
#    Procesando: Tablets - None
#    📊 Filas antes filtrado: 97,459
#    🗑️ Outliers removidos: 381 (0.4%)
#    R² ajuste sinusoidal: 0.607
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Infants
#    🌐 Procesando todas las regiones juntas (49/74 - 66.2%)
#    Procesando: Infants - None
#    📊 Filas antes filtrado: 166,663
#    🗑️ Outliers removidos: 433 (0.3%)
#    R² ajuste sinusoidal: 0.797
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Camping
#    🌐 Procesando todas las regiones juntas (50/74 - 67.6%)
#    Procesando: Camping - None
#    📊 Filas antes filtrado: 107,567
#    🗑️ Outliers removidos: 347 (0.3%)
#    R² ajuste sinusoidal: 0.536
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 792.1 → 792.1 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Learning
#    🌐 Procesando todas las regiones juntas (51/74 - 68.9%)
#    Procesando: Learning - None
#    📊 Filas antes filtrado: 80,710
#    🗑️ Outliers removidos: 212 (0.3%)
#    R² ajuste sinusoidal: 0.510
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Underwear
#    🌐 Procesando todas las regiones juntas (52/74 - 70.3%)
#    Procesando: Underwear - None
#    📊 Filas antes filtrado: 176,186
#    🗑️ Outliers removidos: 528 (0.3%)
#    R² ajuste sinusoidal: 0.789
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Soda
#    🌐 Procesando todas las regiones juntas (53/74 - 71.6%)
#    Procesando: Soda - None
#    📊 Filas antes filtrado: 131,224
#    🗑️ Outliers removidos: 539 (0.4%)
#    R² ajuste sinusoidal: 0.735
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Desktops
#    🌐 Procesando todas las regiones juntas (54/74 - 73.0%)
#    Procesando: Desktops - None
#    📊 Filas antes filtrado: 114,994
#    🗑️ Outliers removidos: 454 (0.4%)
#    R² ajuste sinusoidal: 0.706
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Water Sports
#    🌐 Procesando todas las regiones juntas (55/74 - 74.3%)
#    Procesando: Water Sports - None
#    📊 Filas antes filtrado: 89,161
#    🗑️ Outliers removidos: 258 (0.3%)
#    R² ajuste sinusoidal: 0.485
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 863.4 → 863.4 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Children's Learning
#    🌐 Procesando todas las regiones juntas (56/74 - 75.7%)
#    Procesando: Children's Learning - None
#    📊 Filas antes filtrado: 90,041
#    🗑️ Outliers removidos: 234 (0.3%)
#    R² ajuste sinusoidal: 0.558
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Laptops
#    🌐 Procesando todas las regiones juntas (57/74 - 77.0%)
#    Procesando: Laptops - None
#    📊 Filas antes filtrado: 96,544
#    🗑️ Outliers removidos: 953 (1.0%)
#    R² ajuste sinusoidal: 0.623
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Romance
#    🌐 Procesando todas las regiones juntas (58/74 - 78.4%)
#    Procesando: Romance - None
#    📊 Filas antes filtrado: 127,870
#    🗑️ Outliers removidos: 318 (0.2%)
#    R² ajuste sinusoidal: 0.590
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Nuts
#    🌐 Procesando todas las regiones juntas (59/74 - 79.7%)
#    Procesando: Nuts - None
#    📊 Filas antes filtrado: 207,308
#    🗑️ Outliers removidos: 483 (0.2%)
#    R² ajuste sinusoidal: 0.823
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Headphones
#    🌐 Procesando todas las regiones juntas (60/74 - 81.1%)
#    Procesando: Headphones - None
#    📊 Filas antes filtrado: 141,305
#    🗑️ Outliers removidos: 523 (0.4%)
#    R² ajuste sinusoidal: 0.607
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 876.0 → 876.0 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Shampoo
#    🌐 Procesando todas las regiones juntas (61/74 - 82.4%)
#    Procesando: Shampoo - None
#    📊 Filas antes filtrado: 107,290
#    🗑️ Outliers removidos: 294 (0.3%)
#    R² ajuste sinusoidal: 0.573
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Eyes
#    🌐 Procesando todas las regiones juntas (62/74 - 83.8%)
#    Procesando: Eyes - None
#    📊 Filas antes filtrado: 129,621
#    🗑️ Outliers removidos: 862 (0.7%)
#    R² ajuste sinusoidal: 0.623
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Apparel
#    🌐 Procesando todas las regiones juntas (63/74 - 85.1%)
#    Procesando: Apparel - None
#    📊 Filas antes filtrado: 88,437
#    🗑️ Outliers removidos: 249 (0.3%)
#    R² ajuste sinusoidal: 0.518
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Major Appliances
#    🌐 Procesando todas las regiones juntas (64/74 - 86.5%)
#    Procesando: Major Appliances - None
#    📊 Filas antes filtrado: 100,279
#    🗑️ Outliers removidos: 221 (0.2%)
#    R² ajuste sinusoidal: 0.551
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Soccer
#    🌐 Procesando todas las regiones juntas (65/74 - 87.8%)
#    Procesando: Soccer - None
#    📊 Filas antes filtrado: 78,119
#    🗑️ Outliers removidos: 249 (0.3%)
#    R² ajuste sinusoidal: 0.455
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 790.3 → 790.3 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Canned Goods
#    🌐 Procesando todas las regiones juntas (66/74 - 89.2%)
#    Procesando: Canned Goods - None
#    📊 Filas antes filtrado: 162,464
#    🗑️ Outliers removidos: 444 (0.3%)
#    R² ajuste sinusoidal: 0.719
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Basketball
#    🌐 Procesando todas las regiones juntas (67/74 - 90.5%)
#    📝 Caso especial: asignando ventas = 0
#
# 🎯 PRODUCTO: History
#    🌐 Procesando todas las regiones juntas (68/74 - 91.9%)
#    Procesando: History - None
#    📊 Filas antes filtrado: 138,537
#    🗑️ Outliers removidos: 308 (0.2%)
#    R² ajuste sinusoidal: 0.634
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Small Appliances
#    🌐 Procesando todas las regiones juntas (69/74 - 93.2%)
#    Procesando: Small Appliances - None
#    📊 Filas antes filtrado: 89,831
#    🗑️ Outliers removidos: 187 (0.2%)
#    R² ajuste sinusoidal: 0.407
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Specialty
#    🌐 Procesando todas las regiones juntas (70/74 - 94.6%)
#    Procesando: Specialty - None
#    📊 Filas antes filtrado: 118,314
#    🗑️ Outliers removidos: 232 (0.2%)
#    R² ajuste sinusoidal: 0.516
#    ✅ Generadas 1,050 predicciones
#    🧹 Memoria: 858.2 → 858.2 MB (liberados: 0.0 MB)
#
# 🎯 PRODUCTO: Accessories
#    🌐 Procesando todas las regiones juntas (71/74 - 95.9%)
#    Procesando: Accessories - None
#    📊 Filas antes filtrado: 96,347
#    🗑️ Outliers removidos: 656 (0.7%)
#    R² ajuste sinusoidal: 0.509
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Shirts
#    🌐 Procesando todas las regiones juntas (72/74 - 97.3%)
#    Procesando: Shirts - None
#    📊 Filas antes filtrado: 148,355
#    🗑️ Outliers removidos: 403 (0.3%)
#    R² ajuste sinusoidal: 0.765
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Biography
#    🌐 Procesando todas las regiones juntas (73/74 - 98.6%)
#    Procesando: Biography - None
#    📊 Filas antes filtrado: 120,266
#    🗑️ Outliers removidos: 287 (0.2%)
#    R² ajuste sinusoidal: 0.634
#    ✅ Generadas 1,050 predicciones
#
# 🎯 PRODUCTO: Speakers
#    🌐 Procesando todas las regiones juntas (74/74 - 100.0%)
#    Procesando: Speakers - None
#    📊 Filas antes filtrado: 116,288
#    🗑️ Outliers removidos: 467 (0.4%)
#    R² ajuste sinusoidal: 0.597
#    ✅ Generadas 1,050 predicciones
#
# ==================================================
# ✅ PROCESAMIENTO COMPLETADO
#    - Total predicciones generadas: 77,700
#    - Combinaciones procesadas: 74/74
# ==================================================

# %%
#ordenamos los datos para que sean iguales que en kaggle
store = dict_results.keys()
total_sales = dict_results.values()

sub = pd.DataFrame({
    "STORE_SUBGROUP_DATE_ID": store,
    "TOTAL_SALES": total_sales
})
test_store_ordenado = pd.read_csv('../data/ids_test.csv')
test_store_ordenado = test_store_ordenado.join(sub.set_index('STORE_SUBGROUP_DATE_ID'), on='STORE_SUBGROUP_DATE_ID', how='left') 
print(test_store_ordenado[test_store_ordenado['TOTAL_SALES'].isna()])
test_store_ordenado.to_csv('../data/submission_sin_region_codigo_pred_total_sales.csv', index=False) 
#est_store_ordenado
# Out:
# Empty DataFrame
# Columns: [STORE_SUBGROUP_DATE_ID, TOTAL_SALES]
# Index: []
